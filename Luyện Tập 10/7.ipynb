# %%
while True:
    mk = input("Nhập mật khẩu: ")
    if mk == "python123":
        print("Đúng!")
        break
    else:
        print("Sai, nhập lại!")
# Out:
# Sai, nhập lại!
# Sai, nhập lại!
# Đúng!
